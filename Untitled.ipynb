# %%
import re
import os
import sys
from pprint import pprint

projectDir = "./proj1"

# %%
def getFilesUtils(dirs, files, filePath):
    if type(dirs) is tuple: 
        filePath = dirs[0]
        for dir_ in dirs:
            getFilesUtils(dir_, files, filePath)
            
    elif type(dirs) is list:
        for file in dirs:
            getFilesUtils(file, files, filePath+"/"+file)
        
    elif type(dirs) is str:
        if dirs.endswith(".html"):
            return files["htmlFiles"].update(dict({filePath:set()}))
            
        elif dirs.endswith(".css"):
            return files["cssFiles"].update(dict({filePath:set()}))
        elif dirs.endswith(".js"):
            return files["jsFiles"].update(dict({filePath:set()}))

        
def getFiles():       
    files = {
        "htmlFiles": dict(),
        "cssFiles": dict(),
        "jsFiles": dict(),
    }
    for dirs in os.walk(projectDir):
         getFilesUtils(dirs, files, "") 
    
    return files



def getHTMLClassesTagsIds(files):
    for htmlFile in files['htmlFiles']:
        with open(htmlFile) as f:
            matches= set()
            for line in f.readlines():
                #classes
                classes = [text_find.split() 
                               for text_find in re.findall(r'class[ ]{0,1}\=[ ]{0,1}[\'\"]{1}([ a-zA-Z0-9/_/-]+)[\'\"]{0,1}', line) 
                                   if len(text_find) > 0]
                
                classes = {clas for class_list in classes for clas in class_list}
                for cls in classes:
                    matches.add("." + cls)
                
                #ids
                ids = [text_find.split() 
                               for text_find in re.findall(r'id[ ]{0,1}\=[ ]{0,1}[\'\"]{1}([ a-zA-Z0-9/_/-]+)[\'\"]{0,1}', line) 
                                   if len(text_find) > 0]
                ids = {id_ for id_list in ids for id_ in id_list}
                for id_ in ids:
                    matches.add("#" + id_) 
                    
                #tags
                tags = [text_find.split() 
                               for text_find in re.findall(r'<[ ]*([a-zA-Z0-9]+)', line) 
                                   if len(text_find) > 0]
                tags = {tag for tag_list in tags for tag in tag_list}
                for tag in tags:
                    matches.add(tag)  
                    
            files['htmlFiles'][htmlFile] = matches
     
    
def getJSClassesTagsIds(files):
    for htmlFile in files['cssFiles']:
        with open(htmlFile) as f:
            matches= set()
            for line in f.readlines():
                #classes
                classes = [text_find.split() 
                               for text_find in re.findall(r'class[ ]{0,1}\=[ ]{0,1}[\'\"]{1}([ a-zA-Z0-9/_/-]+)[\'\"]{0,1}', line) 
                                   if len(text_find) > 0]
                
                classes = {clas for class_list in classes for clas in class_list}
                for cls in classes:
                    matches.add("." + cls)
            files['htmlFiles'][htmlFile] = matches

# %%
def getCSSClassesTagsIds(files):
    for cssFile in files['cssFiles']:
        with open(cssFile) as f:
            data=f.read().replace('\n', '')
            matches = [text_find.split() 
                               for text_find in re.findall(r'[\. \#]([ \=\"\'\[\]\(\)a-zA-Z0-9\-\:\>\,/_]+)[ \n]*\{', data) 
                                   if len(text_find) > 0]
            print(cssFile)
            print(matches, "\n\n\n\n\n\n")
            
            #\#\[\]\(\)
#             classes = {clas for class_list in classes for clas in class_list}
#             for cls in classes:
#                 matches.add("." + cls)
#             files['htmlFiles'][htmlFile] = matches
        
        
def main():
    files = getFiles()
    getHTMLClassesTagsIds(files)
    getCSSClassesTagsIds(files)
#     pprint(files)
    
    
if __name__ == "__main__":
    main()
# Out:
# ./proj1/css/index.min.css
# [['wrapper,body,html'], ['wrapper'], ['separator0'], ['separator1'], ['separator1:before'], ['separator1:after'], ['separator1:before'], ['hero-sub'], ['title'], ['hero-sub'], ['background'], ['hero-sub'], ['navbar-toggler-icon'], ['hero-body'], ['footer-links', 'a'], ['hero-carousel'], ['hero-btns'], ['screen', 'and', '(max-width:768px)'], ['hero-body'], ['footer'], ['footer', 'a'], ['footer', 'a:hover'], ['logo'], ['logo', 'img'], ['icon'], ['footer-links'], ['footer-links', 'a'], ['testimonials'], ['left-testimonial'], ['star'], ['right-testimonial'], ['TotalReviews'], ['fixed-height-carousel'], ['quote-carousel'], ['carousel-control'], ['carousel-indicators'], ['carousel-indicators', 'li'], ['active'], ['carousel-item', 'blockquote'], ['carousel-item', 'blockquote', 'p:before'], ['why-section'], ['counter'], ['single_counter', 'h2'], ['single_counter', 'i'], ['single_counter', 'h4'], ['topics'], ['topic'], ['devicon'], ['fa-cog'], ['getStarted'], ['btnType1'], ['btnType1:hover'], ['bt'], ['and', '(max-width:1360px)'], ['hero-sub'], ['and', '(max-width:1040px)'], ['hero-sub'], ['and', '(max-width:720px)'], ['hero-sub'], ['and', '(max-width:540px)'], ['hero-sub'], ['counter_item'], ['hero-sub'], ['counter_item']]
#
#
#
#
#
#
# ./proj1/css/devicon_fonts.min.css
# [['devicon-express-original-wordmark:before'], ['devicon-express-original:before'], ['devicon-devicon-plain-wordmark:before'], ['devicon-devicon-plain:before'], ['devicon-intellij-plain-wordmark:before'], ['devicon-intellij-plain:before'], ['devicon-pycharm-plain-wordmark:before'], ['devicon-pycharm-plain:before'], ['devicon-rubymine-plain-wordmark:before'], ['devicon-rubymine-plain:before'], ['devicon-webstorm-plain-wordmark:before'], ['devicon-webstorm-plain:before'], ['devicon-tomcat-line-wordmark:before'], ['devicon-tomcat-line:before'], ['devicon-vuejs-line-wordmark:before'], ['devicon-vuejs-line:before'], ['devicon-vuejs-plain-wordmark:before'], ['devicon-vuejs-plain:before'], ['devicon-swift-plain-wordmark:before'], ['devicon-swift-plain:before'], ['devicon-webpack-plain-wordmark:before'], ['devicon-webpack-plain:before'], ['devicon-visualstudio-plain-wordmark:before'], ['devicon-visualstudio-plain:before'], ['devicon-slack-plain-wordmark:before'], ['devicon-slack-plain:before'], ['devicon-facebook-plain:before'], ['devicon-typescript-plain:before'], ['devicon-babel-plain:before'], ['devicon-mocha-plain:before'], ['devicon-jasmine-plain-wordmark:before'], ['devicon-jasmine-plain:before'], ['devicon-gatling-plain-wordmark:before'], ['devicon-gatling-plain:before'], ['devicon-ssh-plain-wordmark:before'], ['devicon-ssh-plain:before'], ['devicon-sourcetree-plain-wordmark:before'], ['devicon-sourcetree-plain:before'], ['devicon-phpstorm-plain-wordmark:before'], ['devicon-phpstorm-plain:before'], ['devicon-protractor-plain-wordmark:before'], ['devicon-protractor-plain:before'], ['devicon-gradle-plain-wordmark:before'], ['devicon-gradle-plain:before'], ['devicon-cucumber-plain-wordmark:before'], ['devicon-cucumber-plain:before'], ['devicon-jeet-plain-wordmark:before'], ['devicon-jeet-plain:before'], ['devicon-gitlab-plain-wordmark:before'], ['devicon-gitlab-plain:before'], ['devicon-github-plain-wordmark:before'], ['devicon-github-plain:before'], ['devicon-d3js-plain:before'], ['devicon-confluence-plain-wordmark:before'], ['devicon-confluence-plain:before'], ['devicon-bitbucket-plain-wordmark:before'], ['devicon-bitbucket-plain:before'], ['devicon-safari-line-wordmark:before'], ['devicon-safari-line:before'], ['devicon-safari-plain-wordmark:before'], ['devicon-safari-plain:before'], ['devicon-jetbrains-plain:before'], ['devicon-django-line:before'], ['devicon-django-plain:before'], ['devicon-gimp-plain:before'], ['devicon-redhat-plain-wordmark:before'], ['devicon-redhat-plain:before'], ['devicon-cplusplus-line:before'], ['devicon-cplusplus-plain:before'], ['devicon-csharp-line:before'], ['devicon-csharp-plain:before'], ['devicon-c-line:before'], ['devicon-c-plain:before'], ['devicon-nodewebkit-line-wordmark:before'], ['devicon-nodewebkit-line:before'], ['devicon-nodewebkit-plain-wordmark:before'], ['devicon-nodewebkit-plain:before'], ['devicon-nginx-plain:before'], ['devicon-erlang-plain-wordmark:before'], ['devicon-erlang-plain:before'], ['devicon-doctrine-line-wordmark:before'], ['devicon-doctrine-line:before'], ['devicon-doctrine-plain-wordmark:before'], ['devicon-doctrine-plain:before'], ['devicon-apache-line-wordmark:before'], ['devicon-apache-line:before'], ['devicon-apache-plain-wordmark:before'], ['devicon-apache-plain:before'], ['devicon-go-line:before'], ['devicon-redis-plain-wordmark:before'], ['devicon-redis-plain:before'], ['devicon-meteor-plain-wordmark:before'], ['devicon-meteor-plain:before'], ['devicon-heroku-original-wordmark:before'], ['devicon-heroku-original:before'], ['devicon-heroku-plain-wordmark:before'], ['devicon-heroku-plain:before'], ['devicon-go-plain:before'], ['devicon-docker-plain-wordmark:before'], ['devicon-docker-plain:before'], ['devicon-amazonwebservices-plain:before'], ['devicon-amazonwebservices-plain-wordmark:before'], ['devicon-android-plain-wordmark:before'], ['devicon-android-plain:before'], ['devicon-angularjs-plain-wordmark:before'], ['devicon-angularjs-plain:before'], ['devicon-ap ...
#
#
#
#
#
#
# ./proj1/css/index.css
# [['body'], ['separator0'], ['separator1'], ['separator1:after'], ['separator1:before'], ['title'], ['nav-link'], ['logo:hover'], ['background'], ['hero-sub'], ['navbar-toggler-icon'], ['navbar-toggler-icon'], ['hero-body'], ['hero-carousel'], ['hero-btns'], ['screen', 'and', '(max-width:768px)'], ['hero-body'], ['footer'], ['footer', 'a'], ['footer', 'a:hover'], ['logo'], ['icon'], ['footer-links'], ['footer-links', 'a'], ['testimonials'], ['left-testimonial'], ['star'], ['right-testimonial'], ['TotalReviews'], ['fixed-height-carousel'], ['quote-carousel'], ['carousel-control'], ['carousel-indicators'], ['carousel-indicators', 'li'], ['active'], ['carousel-item', 'blockquote'], ['carousel-item', 'blockquote', 'p:before'], ['why-section'], ['counter'], ['counter'], ['single_counter', 'h2'], ['single_counter', 'i'], ['single_counter', 'h4'], ['topics'], ['topic'], ['devicon'], ['fa-cog'], ['getStarted'], ['btnType1'], ['btnType1:hover'], ['bt'], ['and', '(max-width:3000px)'], ['background'], ['h1'], ['and', '(max-width:2000px)'], ['background'], ['h1'], ['and', '(max-width:1560px)'], ['h1'], ['and', '(max-width:1360px)'], ['h1'], ['hero-sub'], ['and', '(max-width:1040px)'], ['h1'], ['hero-sub'], ['and', '(max-width:720px)'], ['h1'], ['hero-sub'], ['and', '(max-width:540px)'], ['h1'], ['counter_item'], ['and', '(max-width:440px)'], ['h1'], ['background'], ['hero-sub'], ['counter_item'], ['h1'], ['hero-sub'], ['counter_item']]
#
#
#
#
#
#
# ./proj1/css/bootstrap.min.css
# [['ol,ol', 'ul,ul', 'ol,ul', 'ul'], ['h6,h1,h2,h3,h4,h5,h6'], ['h1,h1'], ['h2,h2'], ['h3,h3'], ['h4,h4'], ['h5,h5'], ['h6,h6'], ['lead'], ['display-1'], ['display-2'], ['display-3'], ['display-4'], ['small,small'], ['mark,mark'], ['list-unstyled'], ['list-inline'], ['list-inline-item'], ['list-inline-item:not(:last-child)'], ['initialism'], ['blockquote'], ['blockquote-footer'], ['blockquote-footer::before'], ['img-fluid'], ['img-thumbnail'], ['figure'], ['figure-img'], ['figure-caption'], ['kbd'], ['code'], ['pre-scrollable'], ['container'], ['(min-width:576px)'], ['container'], ['(min-width:768px)'], ['container'], ['(min-width:992px)'], ['container'], ['(min-width:1200px)'], ['container'], ['container-fluid'], ['row'], ['no-gutters'], ['col-xl-auto'], ['col'], ['col-auto'], ['col-1'], ['col-2'], ['col-3'], ['col-4'], ['col-5'], ['col-6'], ['col-7'], ['col-8'], ['col-9'], ['col-10'], ['col-11'], ['col-12'], ['order-first'], ['order-last'], ['order-0'], ['order-1'], ['order-2'], ['order-3'], ['order-4'], ['order-5'], ['order-6'], ['order-7'], ['order-8'], ['order-9'], ['order-10'], ['order-11'], ['order-12'], ['offset-1'], ['offset-2'], ['offset-3'], ['offset-4'], ['offset-5'], ['offset-6'], ['offset-7'], ['offset-8'], ['offset-9'], ['offset-10'], ['offset-11'], ['(min-width:576px)'], ['col-sm'], ['col-sm-auto'], ['col-sm-1'], ['col-sm-2'], ['col-sm-3'], ['col-sm-4'], ['col-sm-5'], ['col-sm-6'], ['col-sm-7'], ['col-sm-8'], ['col-sm-9'], ['col-sm-10'], ['col-sm-11'], ['col-sm-12'], ['order-sm-first'], ['order-sm-last'], ['order-sm-0'], ['order-sm-1'], ['order-sm-2'], ['order-sm-3'], ['order-sm-4'], ['order-sm-5'], ['order-sm-6'], ['order-sm-7'], ['order-sm-8'], ['order-sm-9'], ['order-sm-10'], ['order-sm-11'], ['order-sm-12'], ['offset-sm-0'], ['offset-sm-1'], ['offset-sm-2'], ['offset-sm-3'], ['offset-sm-4'], ['offset-sm-5'], ['offset-sm-6'], ['offset-sm-7'], ['offset-sm-8'], ['offset-sm-9'], ['offset-sm-10'], ['offset-sm-11'], ['(min-width:768px)'], ['col-md'], ['col-md-auto'], ['col-md-1'], ['col-md-2'], ['col-md-3'], ['col-md-4'], ['col-md-5'], ['col-md-6'], ['col-md-7'], ['col-md-8'], ['col-md-9'], ['col-md-10'], ['col-md-11'], ['col-md-12'], ['order-md-first'], ['order-md-last'], ['order-md-0'], ['order-md-1'], ['order-md-2'], ['order-md-3'], ['order-md-4'], ['order-md-5'], ['order-md-6'], ['order-md-7'], ['order-md-8'], ['order-md-9'], ['order-md-10'], ['order-md-11'], ['order-md-12'], ['offset-md-0'], ['offset-md-1'], ['offset-md-2'], ['offset-md-3'], ['offset-md-4'], ['offset-md-5'], ['offset-md-6'], ['offset-md-7'], ['offset-md-8'], ['offset-md-9'], ['offset-md-10'], ['offset-md-11'], ['(min-width:992px)'], ['col-lg'], ['col-lg-auto'], ['col-lg-1'], ['col-lg-2'], ['col-lg-3'], ['col-lg-4'], ['col-lg-5'], ['col-lg-6'], ['col-lg-7'], ['col-lg-8'], ['col-lg-9'], ['col-lg-10'], ['col-lg-11'], ['col-lg-12'], ['order-lg-first'], ['order-lg-last'], ['order-lg-0'], ['order-lg-1'], ['order-lg-2'], ['order-lg-3'], ['order-lg-4'], ['order-lg-5'], ['order-lg-6'], ['order-lg-7'], ['order-lg-8'], ['order-lg-9'], ['order-lg-10'], ['order-lg-11'], ['order-lg-12'], ['offset-lg-0'], ['offset-lg-1'], ['offset-lg-2'], ['offset-lg-3'], ['offset-lg-4'], ['offset-lg-5'], ['offset-lg-6'], ['offset-lg-7'], ['offset-lg-8'], ['offset-lg-9'], ['offset-lg-10'], ['offset-lg-11'], ['(min-width:1200px)'], ['col-xl'], ['col-xl-auto'], ['col-xl-1'], ['col-xl-2'], ['col-xl-3'], ['col-xl-4'], ['col-xl-5'], ['col-xl-6'], ['col-xl-7'], ['col-xl-8'], ['col-xl-9'], ['col-xl-10'], ['col-xl-11'], ['col-xl-12'], ['order-xl-first'], ['order-xl-last'], ['order-xl-0'], ['order-xl-1'], ['order-xl-2'], ['order-xl-3'], ['order-xl-4'], ['order-xl-5'], ['order-xl-6'], ['order-xl-7'], ['order-xl-8'], ['order-xl-9'], ['order-xl-10'], ['order-xl-11'], ['order-xl-12'], ['offset-xl-0'], ['offset-xl-1'], ['offset-xl-2'], ['offset-xl-3'], ['offset-xl-4'], ['offset-xl-5'], ['offset-xl-6'], ['offset-xl-7'], ['offset-xl-8'], ['offset-xl-9'], ['offset-xl-10'], ['offset-xl-11'], ...
